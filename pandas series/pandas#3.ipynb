# %% [markdown]
# # method and attributes

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\91798\Downloads\matches - matches.csv")

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# iloc[st index of row : end index of row : step, st index of column : end index of column : step]

# %%
data.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
# 1,2,3,4

# %%
data.iloc[[1,2,3,4]]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 1           0       Rising Pune Supergiant            0               7
# 2           0        Kolkata Knight Riders            0              10
# ...

# %%
data.iloc[1:5]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 1           0       Rising Pune Supergiant            0               7
# 2           0        Kolkata Knight Riders            0              10
# ...

# %%
# 1,3,5,7

# %%
data.iloc[1:8:2]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 3           0         Kings XI Punjab            0               6
# ...

# %%
# 3

# %%
data.iloc[:,3]
# Out:
# 0      2017-04-05
# 1      2017-04-06
# 2      2017-04-07
# 3      2017-04-08
# 4      2017-04-08
#           ...
# 631    2016-05-22
# 632    2016-05-24
# 633    2016-05-25
# 634    2016-05-27
# 635    2016-05-29
# Name: date, Length: 636, dtype: object

# %%
# 1,3,5

# %%
data.iloc[:,[1,3,5]]
# Out:
#      season        date                        team2
# 0      2017  2017-04-05  Royal Challengers Bangalore
# 1      2017  2017-04-06       Rising Pune Supergiant
# 2      2017  2017-04-07        Kolkata Knight Riders
# 3      2017  2017-04-08              Kings XI Punjab
# 4      2017  2017-04-08             Delhi Daredevils
# ..      ...         ...                          ...
# 631    2016  2016-05-22  Royal Challengers Bangalore
# 632    2016  2016-05-24  Royal Challengers Bangalore
# 633    2016  2016-05-25        Kolkata Knight Riders
# 634    2016  2016-05-27          Sunrisers Hyderabad
# 635    2016  2016-05-29  Royal Challengers Bangalore
#
# [636 rows x 3 columns]

# %%
# 1,2,3,4,5,6

# %%
data.iloc[:,1:7]
# Out:
#      season       city        date                        team1  \
# 0      2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2017       Pune  2017-04-06               Mumbai Indians
# 2      2017     Rajkot  2017-04-07                Gujarat Lions
# 3      2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..      ...        ...         ...                          ...
# 631    2016     Raipur  2016-05-22             Delhi Daredevils
# 632    2016  Bangalore  2016-05-24                Gujarat Lions
# 633    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634    2016      Delhi  2016-05-27                Gujarat Lions
# 635    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore
# 1         Rising Pune Supergiant       Rising Pune Supergiant
# ...

# %%
# 1,3,5,7

# %%
data.iloc[:,1:8:2]
# Out:
#      season        date                        team2 toss_decision
# 0      2017  2017-04-05  Royal Challengers Bangalore         field
# 1      2017  2017-04-06       Rising Pune Supergiant         field
# 2      2017  2017-04-07        Kolkata Knight Riders         field
# 3      2017  2017-04-08              Kings XI Punjab         field
# 4      2017  2017-04-08             Delhi Daredevils           bat
# ..      ...         ...                          ...           ...
# 631    2016  2016-05-22  Royal Challengers Bangalore         field
# 632    2016  2016-05-24  Royal Challengers Bangalore         field
# 633    2016  2016-05-25        Kolkata Knight Riders         field
# 634    2016  2016-05-27          Sunrisers Hyderabad         field
# 635    2016  2016-05-29  Royal Challengers Bangalore           bat
#
# [636 rows x 4 columns]

# %%
# masking 
mask=data['city']=="Hyderabad"
mask
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
data[mask].shape[0]
# Out:
# 49

# %%
mask1=data['date']>'2017-01-01'

# %%
type(mask1)
# Out:
# pandas.core.series.Series

# %%
data[mask1].shape[0]
# Out:
# 59

# %%
# 2017 and hy

# %%
m1=data['season']==2017

# %%
m1
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: season, Length: 636, dtype: bool

# %%
m2=data['city']=="Hyderabad"

# %%
m2
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
data[m1 & m2]
# Out:
#     id  season       city        date                   team1  \
# 0    1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 5    6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 18  19    2017  Hyderabad  2017-04-17     Sunrisers Hyderabad
# 20  21    2017  Hyderabad  2017-04-19     Sunrisers Hyderabad
# 35  36    2017  Hyderabad  2017-04-30     Sunrisers Hyderabad
# 42  43    2017  Hyderabad  2017-05-06  Rising Pune Supergiant
# 46  47    2017  Hyderabad  2017-05-08          Mumbai Indians
# 58  59    2017  Hyderabad  2017-05-21          Mumbai Indians
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# ...
